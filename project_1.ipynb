# %%
import csv
import numpy as np
import pandas as pd
import os
from subprocess import check_output
import matplotlib.pyplot as plt

csv_file = "City_of_Seattle_Wages_2.csv"

# %%
wage_df = pd.read_csv(csv_file)
wage_df.head()
# Out:
#                   Department           Jobtitle  Female Avg Hrly Rate  \
# 0  Arts and Cultural Affairs         Accountant                   NaN
# 1  Arts and Cultural Affairs      Actg Tech III                 26.79
# 2  Arts and Cultural Affairs     Admin Spec III                 26.26
# 3  Arts and Cultural Affairs   Admin Staff Asst                 31.76
# 4  Arts and Cultural Affairs  Arts Conserv Tech                 27.78
#
#    No. Female Empl  Male Avg Hrly Rate  No. Male Empl  Total Avg Hrly Rate  \
# 0              NaN               29.75            1.0                29.75
# 1              1.0                 NaN            NaN                26.79
# 2              1.0                 NaN            NaN                26.26
# 3              2.0                 NaN            NaN                31.76
# 4              1.0               27.78            1.0                27.78
#
#    Total No. Empl  \
# 0               1
# 1               1
# 2               1
# 3               2
# 4               2
#
#    Total Average of MONTHS LONGEVITY IN CURRENT CLASSIFICATION   \
# 0                                               39.0
# 1                                               56.0
# 2                                               37.0
# 3                                               99.0
# 4                                               65.0
#
#    Ratio of women's hourly rate to men's hourly rate - percentage  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              100.0
#
#                Notes
# 0  No women in title
# 1    No men in title
# 2    No men in title
# 3    No men in title
# 4                NaN

# %%
wage_df["No. Female Empl"].fillna(0, inplace=True)
wage_df
# Out:
#                      Department                    Jobtitle  \
# 0     Arts and Cultural Affairs                  Accountant
# 1     Arts and Cultural Affairs               Actg Tech III
# 2     Arts and Cultural Affairs              Admin Spec III
# 3     Arts and Cultural Affairs            Admin Staff Asst
# 4     Arts and Cultural Affairs           Arts Conserv Tech
# ...                         ...                         ...
# 1642   Seattle Public Utilities      Wtrshed Resources Tech
# 1643   Seattle Public Utilities  Wtrworks Maint Spec,Sr-SMU
# 1644   Seattle Public Utilities     Wtrworks Maint Spec-SMU
# 1645   Seattle Public Utilities         Wtrworks Maint Supv
# 1646                        NaN                 Grand Total
#
#       Female Avg Hrly Rate  No. Female Empl  Male Avg Hrly Rate  \
# 0                      NaN              0.0               29.75
# 1                    26.79              1.0                 NaN
# 2                    26.26              1.0                 NaN
# 3                    31.76              2.0                 NaN
# 4                    27.78              1.0               27.78
# ...                    ...              ...                 ...
# 1642                   NaN              0.0               34.45
# 1643                   NaN              0.0               29.99
# 1644                   NaN              0.0               27.65
# 1645                   NaN              0.0               35.57
# 1646                 35.45           3577.0               39.15
#
#       No. Male Empl  Total Avg Hrly Rate  Total No. Empl  \
# 0               1.0                29.75               1
# 1               NaN                26.79               1
# 2               NaN                26.26               1
# 3               NaN                31.76               2
# 4               1.0                27.78               2
# ...             ...                  ...             ...
# 1642            1.0                34.45               1
# 1643            2.0                29.99               2
# 1644            3.0                27.65               3
# 1645            1.0                35.57               1
# 1646         6240.0                37.80            9817
#
#       Total Average of MONTHS LONGEVITY IN CURRENT CLASSIFICATION   \
# 0                                                 39.00
# 1                                                 56.00
# 2                                                 37.00
# 3                                                 99.00
# 4                                                 65.00
# ...                                                 ...
# 1642                                              73.00
# 1643                                              43.00
# 1644                                              47.00
# 1645                                              14.00
# 1646                                              79.58
#
#       Ratio of women's hourly rate to men's hourly rate - percentage  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                 100.0
# ...                                                 ...
# 1642                                                NaN
# 1643                                                NaN
# 1644                                                NaN
# 1645                                                NaN
# 1646                                                NaN
#
#                   Notes
# 0     No women in title
# 1       No men in title
# 2       No men in title
# 3       No men in title
# 4                   NaN
# ...                 ...
# 1642  No women in title
# 1643  No women in title
# 1644  No women in title
# 1645  No women in title
# 1646                NaN
#
# [1647 rows x 11 columns]

# %%
wage_df["No. Male Empl"].fillna(0, inplace=True)
wage_df
# Out:
#                      Department                    Jobtitle  \
# 0     Arts and Cultural Affairs                  Accountant
# 1     Arts and Cultural Affairs               Actg Tech III
# 2     Arts and Cultural Affairs              Admin Spec III
# 3     Arts and Cultural Affairs            Admin Staff Asst
# 4     Arts and Cultural Affairs           Arts Conserv Tech
# ...                         ...                         ...
# 1642   Seattle Public Utilities      Wtrshed Resources Tech
# 1643   Seattle Public Utilities  Wtrworks Maint Spec,Sr-SMU
# 1644   Seattle Public Utilities     Wtrworks Maint Spec-SMU
# 1645   Seattle Public Utilities         Wtrworks Maint Supv
# 1646                        NaN                 Grand Total
#
#       Female Avg Hrly Rate  No. Female Empl  Male Avg Hrly Rate  \
# 0                      NaN              0.0               29.75
# 1                    26.79              1.0                 NaN
# 2                    26.26              1.0                 NaN
# 3                    31.76              2.0                 NaN
# 4                    27.78              1.0               27.78
# ...                    ...              ...                 ...
# 1642                   NaN              0.0               34.45
# 1643                   NaN              0.0               29.99
# 1644                   NaN              0.0               27.65
# 1645                   NaN              0.0               35.57
# 1646                 35.45           3577.0               39.15
#
#       No. Male Empl  Total Avg Hrly Rate  Total No. Empl  \
# 0               1.0                29.75               1
# 1               0.0                26.79               1
# 2               0.0                26.26               1
# 3               0.0                31.76               2
# 4               1.0                27.78               2
# ...             ...                  ...             ...
# 1642            1.0                34.45               1
# 1643            2.0                29.99               2
# 1644            3.0                27.65               3
# 1645            1.0                35.57               1
# 1646         6240.0                37.80            9817
#
#       Total Average of MONTHS LONGEVITY IN CURRENT CLASSIFICATION   \
# 0                                                 39.00
# 1                                                 56.00
# 2                                                 37.00
# 3                                                 99.00
# 4                                                 65.00
# ...                                                 ...
# 1642                                              73.00
# 1643                                              43.00
# 1644                                              47.00
# 1645                                              14.00
# 1646                                              79.58
#
#       Ratio of women's hourly rate to men's hourly rate - percentage  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                 100.0
# ...                                                 ...
# 1642                                                NaN
# 1643                                                NaN
# 1644                                                NaN
# 1645                                                NaN
# 1646                                                NaN
#
#                   Notes
# 0     No women in title
# 1       No men in title
# 2       No men in title
# 3       No men in title
# 4                   NaN
# ...                 ...
# 1642  No women in title
# 1643  No women in title
# 1644  No women in title
# 1645  No women in title
# 1646                NaN
#
# [1647 rows x 11 columns]

# %%
wage_df.drop('Notes', axis=1)
# Out:
#                      Department                    Jobtitle  \
# 0     Arts and Cultural Affairs                  Accountant
# 1     Arts and Cultural Affairs               Actg Tech III
# 2     Arts and Cultural Affairs              Admin Spec III
# 3     Arts and Cultural Affairs            Admin Staff Asst
# 4     Arts and Cultural Affairs           Arts Conserv Tech
# ...                         ...                         ...
# 1642   Seattle Public Utilities      Wtrshed Resources Tech
# 1643   Seattle Public Utilities  Wtrworks Maint Spec,Sr-SMU
# 1644   Seattle Public Utilities     Wtrworks Maint Spec-SMU
# 1645   Seattle Public Utilities         Wtrworks Maint Supv
# 1646                        NaN                 Grand Total
#
#       Female Avg Hrly Rate  No. Female Empl  Male Avg Hrly Rate  \
# 0                      NaN              0.0               29.75
# 1                    26.79              1.0                 NaN
# 2                    26.26              1.0                 NaN
# 3                    31.76              2.0                 NaN
# 4                    27.78              1.0               27.78
# ...                    ...              ...                 ...
# 1642                   NaN              0.0               34.45
# 1643                   NaN              0.0               29.99
# 1644                   NaN              0.0               27.65
# 1645                   NaN              0.0               35.57
# 1646                 35.45           3577.0               39.15
#
#       No. Male Empl  Total Avg Hrly Rate  Total No. Empl  \
# 0               1.0                29.75               1
# 1               0.0                26.79               1
# 2               0.0                26.26               1
# 3               0.0                31.76               2
# 4               1.0                27.78               2
# ...             ...                  ...             ...
# 1642            1.0                34.45               1
# 1643            2.0                29.99               2
# 1644            3.0                27.65               3
# 1645            1.0                35.57               1
# 1646         6240.0                37.80            9817
#
#       Total Average of MONTHS LONGEVITY IN CURRENT CLASSIFICATION   \
# 0                                                 39.00
# 1                                                 56.00
# 2                                                 37.00
# 3                                                 99.00
# 4                                                 65.00
# ...                                                 ...
# 1642                                              73.00
# 1643                                              43.00
# 1644                                              47.00
# 1645                                              14.00
# 1646                                              79.58
#
#       Ratio of women's hourly rate to men's hourly rate - percentage
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                 100.0
# ...                                                 ...
# 1642                                                NaN
# 1643                                                NaN
# 1644                                                NaN
# 1645                                                NaN
# 1646                                                NaN
#
# [1647 rows x 10 columns]

# %%
wage_df.describe()
# Out:
#        Female Avg Hrly Rate  No. Female Empl  Male Avg Hrly Rate  \
# count           1112.000000      1647.000000         1148.000000
# mean              37.572914         4.343655           39.020906
# std               11.170982        88.217434           12.283102
# min                5.110000         0.000000            5.110000
# 25%               29.215000         0.000000           30.280000
# 50%               36.300000         1.000000           37.700000
# 75%               44.740000         2.000000           45.965000
# max               86.340000      3577.000000          117.320000
#
#        No. Male Empl  Total Avg Hrly Rate  Total No. Empl  \
# count    1647.000000          1647.000000     1647.000000
# mean        7.577413            38.449174       11.921069
# std       154.590727            11.854552      242.560581
# min         0.000000             5.110000        1.000000
# 25%         0.000000            29.990000        1.000000
# 50%         1.000000            36.680000        2.000000
# 75%         3.000000            45.300000        5.000000
# max      6240.000000           117.320000     9817.000000
#
#        Total Average of MONTHS LONGEVITY IN CURRENT CLASSIFICATION   \
# count                                        1647.000000
# mean                                           76.188039
# std                                            56.108034
# min                                             0.000000
# 25%                                            37.960000
# 50%                                            65.000000
# 75%                                           102.935000
# max                                           382.000000
#
#        Ratio of women's hourly rate to men's hourly rate - percentage
# count                                         606.000000
# mean                                          100.215429
# std                                             4.631025
# min                                            74.820000
# 25%                                            99.432500
# 50%                                           100.000000
# 75%                                           101.250000
# max                                           129.890000

# %%
number_female = wage_df.groupby('Jobtitle')['No. Female Empl'].count()
number_female
# Out:
# Jobtitle
# Accountant                    12
# Accountant,Prin                8
# Accountant,Sr                  9
# Act Exec                       2
# Actg Tech I                    1
#                               ..
# Wtrshed Resource Spec          1
# Wtrshed Resources Tech         1
# Wtrworks Maint Spec,Sr-SMU     1
# Wtrworks Maint Spec-SMU        1
# Wtrworks Maint Supv            1
# Name: No. Female Empl, Length: 868, dtype: int64

# %%
number_male = wage_df.groupby('Jobtitle')['No. Female Empl'].count()
number_male
# Out:
# Jobtitle
# Accountant                    12
# Accountant,Prin                8
# Accountant,Sr                  9
# Act Exec                       2
# Actg Tech I                    1
#                               ..
# Wtrshed Resource Spec          1
# Wtrshed Resources Tech         1
# Wtrworks Maint Spec,Sr-SMU     1
# Wtrworks Maint Spec-SMU        1
# Wtrworks Maint Supv            1
# Name: No. Female Empl, Length: 868, dtype: int64

# %%
#dataframe_name['column_name'].interpolate(method ='linear', limit_direction ='forward')

wage_df['Male Avg Hrly Rate'].interpolate(method = 'linear', limit_direction = 'forward')
# Out:
# 0       29.7500
# 1       29.2575
# 2       28.7650
# 3       28.2725
# 4       27.7800
#          ...
# 1642    34.4500
# 1643    29.9900
# 1644    27.6500
# 1645    35.5700
# 1646    39.1500
# Name: Male Avg Hrly Rate, Length: 1647, dtype: float64

# %%
wage_df['Female Avg Hrly Rate'].interpolate(method = 'linear', limit_direction = 'backward')
# Out:
# 0       26.790000
# 1       26.790000
# 2       26.260000
# 3       31.760000
# 4       27.780000
#           ...
# 1642    35.158571
# 1643    35.231429
# 1644    35.304286
# 1645    35.377143
# 1646    35.450000
# Name: Female Avg Hrly Rate, Length: 1647, dtype: float64

# %%
wage_df
# Out:
#                      Department                    Jobtitle  \
# 0     Arts and Cultural Affairs                  Accountant
# 1     Arts and Cultural Affairs               Actg Tech III
# 2     Arts and Cultural Affairs              Admin Spec III
# 3     Arts and Cultural Affairs            Admin Staff Asst
# 4     Arts and Cultural Affairs           Arts Conserv Tech
# ...                         ...                         ...
# 1642   Seattle Public Utilities      Wtrshed Resources Tech
# 1643   Seattle Public Utilities  Wtrworks Maint Spec,Sr-SMU
# 1644   Seattle Public Utilities     Wtrworks Maint Spec-SMU
# 1645   Seattle Public Utilities         Wtrworks Maint Supv
# 1646                        NaN                 Grand Total
#
#       Female Avg Hrly Rate  No. Female Empl  Male Avg Hrly Rate  \
# 0                      NaN              0.0               29.75
# 1                    26.79              1.0                 NaN
# 2                    26.26              1.0                 NaN
# 3                    31.76              2.0                 NaN
# 4                    27.78              1.0               27.78
# ...                    ...              ...                 ...
# 1642                   NaN              0.0               34.45
# 1643                   NaN              0.0               29.99
# 1644                   NaN              0.0               27.65
# 1645                   NaN              0.0               35.57
# 1646                 35.45           3577.0               39.15
#
#       No. Male Empl  Total Avg Hrly Rate  Total No. Empl  \
# 0               1.0                29.75               1
# 1               0.0                26.79               1
# 2               0.0                26.26               1
# 3               0.0                31.76               2
# 4               1.0                27.78               2
# ...             ...                  ...             ...
# 1642            1.0                34.45               1
# 1643            2.0                29.99               2
# 1644            3.0                27.65               3
# 1645            1.0                35.57               1
# 1646         6240.0                37.80            9817
#
#       Total Average of MONTHS LONGEVITY IN CURRENT CLASSIFICATION   \
# 0                                                 39.00
# 1                                                 56.00
# 2                                                 37.00
# 3                                                 99.00
# 4                                                 65.00
# ...                                                 ...
# 1642                                              73.00
# 1643                                              43.00
# 1644                                              47.00
# 1645                                              14.00
# 1646                                              79.58
#
#       Ratio of women's hourly rate to men's hourly rate - percentage  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                 100.0
# ...                                                 ...
# 1642                                                NaN
# 1643                                                NaN
# 1644                                                NaN
# 1645                                                NaN
# 1646                                                NaN
#
#                   Notes
# 0     No women in title
# 1       No men in title
# 2       No men in title
# 3       No men in title
# 4                   NaN
# ...                 ...
# 1642  No women in title
# 1643  No women in title
# 1644  No women in title
# 1645  No women in title
# 1646                NaN
#
# [1647 rows x 11 columns]

# %%
number_employees_male = wage_df.groupby("Department").agg({"No. Male Empl":"sum"})
number_employees_male
# Out:
#                                 No. Male Empl
# Department
# Arts and Cultural Affairs                 8.0
# City Auditor                              2.0
# City Budget Office                       10.0
# City Employees Retirement Syst            4.0
# City Light                             1169.0
# Civil Service Commissions                 5.0
# Department of Planning & Dev            177.0
# Dept of Finance & Admn Svc              272.0
# Ethics And Elections                      4.0
# Fire Department                         936.0
# Hearing Examiner                          0.0
# Housing                                  17.0
# Human Services                           65.0
# Immigrant & Refugee Affairs               2.0
# Information Technology Dept             120.0
# Intergovernmental Relations               6.0
# Law Department                           50.0
# Legislative-City Council                 34.0
# Mayor's Office                           11.0
# Municipal Court                          70.0
# Neighborhoods Department                 16.0
# Office for Civil Rights                   8.0
# Office of Economic Development           13.0
# Office of Sustainability & Env            4.0
# Parks Department                        526.0
# Personnel Department                     17.0
# Police Department                      1308.0
# Police Pension System                     1.0
# Seattle Center                          139.0
# Seattle Dept of Transportation          450.0
# Seattle Public Utilities                796.0

# %%
chart_data = number_employees_male.loc[number_employees_male["Department"] == "City Light"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Department'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-a85d887e7840> in <module>
# ----> 1 chart_data = number_employees_male.loc[number_employees_male["Department"] == "City Light"]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Department'

# %%
plt.pie(number_employees_male)
# Out:
# C:\Users\gjsan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.
# ([<matplotlib.patches.Wedge at 0x1b542d79688>,
#   <matplotlib.patches.Wedge at 0x1b542d79b48>,
#   <matplotlib.patches.Wedge at 0x1b542d82288>,
#   <matplotlib.patches.Wedge at 0x1b542d82848>,
#   <matplotlib.patches.Wedge at 0x1b542d8b108>,
#   <matplotlib.patches.Wedge at 0x1b542d8b7c8>,
#   <matplotlib.patches.Wedge at 0x1b542d8bb08>,
#   <matplotlib.patches.Wedge at 0x1b542d95108>,
#   <matplotlib.patches.Wedge at 0x1b542d82e08>,
#   <matplotlib.patches.Wedge at 0x1b542d8b4c8>,
#   <matplotlib.patches.Wedge at 0x1b542d32e08>,
#   <matplotlib.patches.Wedge at 0x1b542d9e7c8>,
#   <matplotlib.patches.Wedge at 0x1b542d9ee08>,
#   <matplotlib.patches.Wedge at 0x1b542da9488>,
#   <matplotlib.patches.Wedge at 0x1b542da9ac8>,
#   <matplotlib.patches.Wedge at 0x1b542db3148>,
#   <matplotlib.patches.Wedge at 0x1b542db3788>,
#   <matplotlib.patches.Wedge at 0x1b542db3dc8>,
#   <matplotlib.patches.Wedge at 0x1b542dbc448>,
#   <matplotlib.patches.Wedge at 0x1b542dbca88>,
#   <matplotlib.patches.Wedge at 0x1b542dc5108>,
#   <matplotlib.patches.Wedge at 0x1b542dc5748>,
#   <matplotlib.patches.Wedge at 0x1b542dc5d88>,
#   <matplotlib.patches.Wedge at 0x1b542dcd408>,
#   <matplotlib.patches.Wedge at 0x1b542dcda48>,
#   <matplotlib.patches.Wedge at 0x1b542dd80c8>,
#   <matplotlib.patches.Wedge at 0x1b542dd8708>,
#   <matplotlib.patches.Wedge at 0x1b542dd8d48>,
#   <matplotlib.patches.Wedge at 0x1b542de13c8>,
#   <matplotlib.patches.Wedge at 0x1b542de1a08>,
#   <matplotlib.patches.Wedge at 0x1b542deb088>],
#  [Text(1.0999910777853041, 0.004430439337742449, ''),
#   Text(1.099954831536163, 0.009968379018260056, ''),
#   Text(1.099874533572938, 0.0166135606572525, ''),
#   Text(1.0997301136819164, 0.02436548914262668, ''),
#   Text(0.8999010070128824, 0.632596378093647, ''),
#   Text(0.39472175269772686, 1.0267398589454073, ''),
#   Text(0.2991175067110411, 1.0585502903400341, ''),
#   Text(0.05425104243498106, 1.098661378403154, ''),
#   Text(-0.09844561667271577, 1.0955858983018762, ''),
#   Text(-0.5869759606230158, 0.9303006082179501, ''),
#   Text(-0.9453470590212701, 0.562422383978301, ''),
#   Text(-0.9501260509945406, 0.5543108218513505, ''),
#   Text(-0.9721940232322088, 0.5146248936765221, ''),
#   Text(-0.9889969317632161, 0.481544462083144, ''),
#   Text(-1.0166908422977161, 0.41992824528478745, ''),
#   Text(-1.0412665904797225, 0.35463204529587283, ''),
#   Text(-1.0508498659431915, 0.325137754262984, ''),
#   Text(-1.063656478815862, 0.28041914177359906, ''),
#   Text(-1.0697360660629391, 0.25625133943881584, ''),
#   Text(-1.079293794397663, 0.21242623513750594, ''),
#   Text(-1.0874769574001337, 0.1655109275055518, ''),
#   Text(-1.089397400498885, 0.15235912767626436, ''),
#   Text(-1.090947326403249, 0.14083298979146638, ''),
#   Text(-1.0921127192008562, 0.1314907166293949, ''),
#   Text(-1.0881347532029735, -0.16112963374843284, ''),
#   Text(-1.0042230895878823, -0.4489275958755133, ''),
#   Text(-0.5111954875492445, -0.974001629110183, ''),
#   Text(0.19228543136458257, -1.0830633928283868, ''),
#   Text(0.26808392265494224, -1.0668322316156083, ''),
#   Text(0.5681234211992041, -0.9419319393060797, ''),
#   Text(1.0128436234901945, -0.4291244508942053, '')])

# %%
# wage_df.groupby(
#    ['Department']
# ).agg(
#     {
#          'Total No. Empl':sum,    # Sum duration per group
#          'No. Male Empl': "count",  # get the count of females
#          'No. Female Empl': "count",  # get the count of males
#          'Female Avg Hrly Rate': "count",
#          'Male Avg Hrly Rate': "count"
#     }
# )
